# %% [markdown]
# <a href="https://colab.research.google.com/github/nidawahid28/project-4-assignments/blob/main/online_class_projects_02_intermediate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print("High Low Game")

rounds = 5

def main():
    print("Welcome to the High-Low Game!")
    print("*****************************")

    your_score = 0

    for i in range(rounds):
        print(f"\nRound {i + 1}")

        computer_number = random.randint(1, 100)
        your_number = random.randint(1, 100)
        print("Your number is:", your_number)

        choice = input("Do you think your number is *higher* or *lower* than the computer's number? ").strip().lower()

        while choice not in ["higher", "lower"]:
            choice = input("Invalid input. Please type 'higher' or 'lower': ").strip().lower()

        higher_and_correct = choice == "higher" and your_number > computer_number
        lower_and_correct = choice == "lower" and your_number < computer_number

        if higher_and_correct or lower_and_correct:
            print("✅ Correct! The computer's number was", computer_number)
            your_score += 1
        else:
            print("❌ Incorrect! The computer's number was", computer_number)

        print("Your score is now:", your_score)

    print("\n🎮 Thanks for playing the High-Low Game!")
    print(f"Your final score: {your_score} out of {rounds}")

if __name__ == "__main__":
    main()
# Out:
# High Low Game
# Welcome to the High-Low Game!
# *****************************
#
# Round 1
# Your number is: 69
# Do you think your number is *higher* or *lower* than the computer's number? higher
# ❌ Incorrect! The computer's number was 86
# Your score is now: 0
#
# Round 2
# Your number is: 20
# Do you think your number is *higher* or *lower* than the computer's number? low
# Invalid input. Please type 'higher' or 'lower': lower
# ✅ Correct! The computer's number was 92
# Your score is now: 1
#
# Round 3
# Your number is: 80
# Do you think your number is *higher* or *lower* than the computer's number? higher
# ❌ Incorrect! The computer's number was 92
# Your score is now: 1
#
# Round 4
# Your number is: 31
# Do you think your number is *higher* or *lower* than the computer's number? higher
# ❌ Incorrect! The computer's number was 55
# Your score is now: 1
#
# Round 5
# Your number is: 2
# Do you think your number is *higher* or *lower* than the computer's number? lower
# ✅ Correct! The computer's number was 71
# Your score is now: 2
#
# 🎮 Thanks for playing the High-Low Game!
# Your final score: 2 out of 5

# %%
print("Planetary Weight Calculator")

def main():
  print("Welcome to the Planetary Weight Calculator!")
  print("*******************************************")

  earth_weight = float(input("Enter your weight on Earth: "))

  gravity_ratios = {
    "Mercury" : 0.376,
    "Venus"  : 0.889,
    "Mars" : 0.378,
    "Jupiter" : 2.36,
    "Saturn" : 1.081,
    "Uranus" : 0.815,
    "Neptune" : 1.14
}

  print("Select a planet to calculate your weight on:")
  for planet in gravity_ratios:
    print(f'{planet}')

  planet_choice = input("Enter the name of the planet: ").title()

  if planet_choice in gravity_ratios:
    weight_on_planet = earth_weight * gravity_ratios[planet_choice]
    print(f"Your weight on {planet_choice} is {weight_on_planet:.2f} kg.")
  else:
    print("Invalid planet choice!")

if __name__ == "__main__":
  main()
# Out:
# Planetary Weight Calculator
# Welcome to the Planetary Weight Calculator!
# *******************************************
# Enter your weight on Earth: 120
# Select a planet to calculate your weight on:
# Mercury
# Venus
# Mars
# Jupiter
# Saturn
# Uranus
# Neptune
# Enter the name of the planet: mars
# Your weight on Mars is 45.36 kg.

# %%
print("Lists and Dicts.")

my_list = ["apple", "mango", "orange", "pear", "peach"]

def access_element(my_list, index):
  """Returns the element at the specified index, or an error message if out of range."""
  if 0 <= index < len(my_list):
    return f'Element at index {index}: {my_list[index]}'
  return "Index out of range."

def modify_element(my_list, index, new_value):
  """Modifies the element at the specified index with the new value"""
  if 0 <= index < len(my_list):
    old_value = my_list[index]
    my_list[index] = new_value
    return f'Element at index {index} modified from {old_value} to {new_value}'
  return "Index out of range."

def slice_list(my_list, start_index, end_index):
  if 0 <= start_index < len(my_list) and 0 <= end_index <= len(my_list):
    return f'Sliced list: {my_list[start_index:end_index]}'
  return("Invalid slice indices.")

def list_game():
  print("\nWelcome to the list manipulation!")

  my_list = ["apple", "mango", "orange", "pear", "peach"]

  while True:
    print("\nCurrent List:", my_list)
    print("\nSelect an option:")
    print("1. Access Element")
    print("2. Modify Element")
    print("3. Slice List")
    print("4. Quit")
    choice = input("Enter your choice (1-4): ")

    if choice == "1":
      index = int(input("Enter the index of the element to access: "))
      print(access_element(my_list, index))
    elif choice == "2":
      index = int(input("Enter the index of the element to modify! "))
      new_value =input("Enter the new value for the element: ")
      print(modify_element(my_list, index, new_value))
    elif choice == "3":
      start_index = int(input("Enter the starting index of slice: "))
      end_index = int(input("Enter the ending index of slice: "))
      print(slice_list(my_list, start_index,end_index))
    elif choice == "4":
      print("Exiting the game, Thanks for playing!")
      break
    else:
      print("Invalid choice. Please enter a number between 1 to 4.")

if __name__ == "__main__":
  list_game()
# Out:
# Lists and Dicts.
#
# Welcome to the list manipulation!
#
# Current List: ['apple', 'mango', 'orange', 'pear', 'peach']
#
# Select an option:
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1-4): 1
# Enter the index of the element to access: 4
# Element at index 4: peach
#
# Current List: ['apple', 'mango', 'orange', 'pear', 'peach']
#
# Select an option:
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1-4): 2
# Enter the index of the element to modify! 3
# Enter the new value for the element: banana
# Element at index 3 modified from pear to banana
#
# Current List: ['apple', 'mango', 'orange', 'banana', 'peach']
#
# Select an option:
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1-4): 3
# Enter the starting index of slice: 2
# Enter the ending index of slice: 5
# Sliced list: ['orange', 'banana', 'peach']
#
# Current List: ['apple', 'mango', 'orange', 'banana', 'peach']
#
# Select an option:
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1-4): 4
# Exiting the game, Thanks for playing!
