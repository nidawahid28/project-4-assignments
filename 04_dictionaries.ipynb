# %% [markdown]
# <a href="https://colab.research.google.com/github/nidawahid28/project-4-assignments/blob/main/04_dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("00_count_nums.")

def count_numbers():
  count_dict = {}

  while True:
    num = input("Please enter a number (or 'Exit' to quit): ")
    if num.lower() == 'exit':
      break

    if num.isdigit():
        num = int(num)
        count_dict[num] = count_dict.get(num, 0) + 1
    else:
      print("Invalid input. Please enter a number or 'Exit'.")

  return count_dict

def display_counts(count_dict):
  print("\n Number Counts:")
  for key, value in count_dict.items():
    print(f'{key} appears {value} times.')

if __name__=="__main__":
  count = count_numbers()
  display_counts(count)
# Out:
# 00_count_nums.
# Please enter a number (or 'Exit' to quit): 2
# Please enter a number (or 'Exit' to quit): 2
# Please enter a number (or 'Exit' to quit): 3
# Please enter a number (or 'Exit' to quit): 5
# Please enter a number (or 'Exit' to quit): 4
# Please enter a number (or 'Exit' to quit): 5
# Please enter a number (or 'Exit' to quit): 4
# Please enter a number (or 'Exit' to quit): 3
# Please enter a number (or 'Exit' to quit): 5
# Please enter a number (or 'Exit' to quit): 4
# Please enter a number (or 'Exit' to quit): 3
# Please enter a number (or 'Exit' to quit): Exit
#
#  Number Counts:
# 2 appears 2 times.
# 3 appears 3 times.
# 5 appears 3 times.
# 4 appears 3 times.

# %%
print("01_phonebook.")

def add_contact(phonebook):
  name = input("Enter contact name: ")
  number = input("Enter contact number: ")

  if name in phonebook:
    print(f'{name} already exists in the phonebook.')
  else:
   phonebook[name] = number
   print(f'{name} added to the phonebook.')

def search_contact(phonebook):
  name = input("Enter contact name to search: ")

  if name in phonebook:
    print(f'{name}: {phonebook[name]}')
  else:
    print(f'{name} not found in the phone book.')

def delete_contact(phonebook):
  name = input("Enter contact name to delete: ")
  if name in phonebook:
    del phonebook[name]
    print(f'{name} deleted from the phonebook.')
  else:
    print(f'{name} not found in the phonebook.')

def display_contact(phonebook):
  if phonebook:
    print("\nPhonebook Contacts List")
    for name, number in phonebook.items():
      print(f'{name}: {number}')
  else:
    print("Phonebook is empty.")

if __name__=="__main__":
  phonebook = {}

  while True:
    print("\nPhonebook Menu")
    print("1. Add Contact")
    print("2. Search Contact")
    print("3. Delete Contact")
    print("4. Display Contacts")
    print("5. Exit")

    choice = input("Enter your choice(1-5): ")

    if choice == '1':
      add_contact(phonebook)
    elif choice == '2':
      search_contact(phonebook)
    elif choice == '3':
      delete_contact(phonebook)
    elif choice == '4':
      display_contact(phonebook)
    elif choice == '5':
      print("Exiting Phonebook. Goodbye!")
      break
    else:
      print("Invalid choice. Please enter a number between 1 to 5.")
# Out:
# 01_phonebook.
#
# Phonebook Menu
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice(1-5): sara
# Invalid choice. Please enter a number between 1 to 5.
#
# Phonebook Menu
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice(1-5): 03421567845
# Invalid choice. Please enter a number between 1 to 5.
#
# Phonebook Menu
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice(1-5): 2
# Enter contact name to search: sara
# sara not found in the phone book.
#
# Phonebook Menu
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice(1-5): 1
# Enter contact name: zara
# Enter contact number: 03224567896
# zara added to the phonebook.
#
# Phonebook Menu
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice(1-5): 4
#
# ...

# %%
print("02_fruit_shop.")

def main():
    print("03_fruit_shop.")

    fruits = {
        'apple': 1.5,
        'durian': 50,
        'jackfruit': 80,
        'kiwi': 1,
        'rambutan': 1.5,
        'mango': 5
    }

    total_cost = 0

    for fruit_name, price in fruits.items():
        while True:
            try:
                amount_bought = int(input(f"How many ({fruit_name.capitalize()}) do you want to buy?: "))
                if amount_bought < 0:
                    print("Please enter a non-negative number.")
                    continue
                total_cost += price * amount_bought
                break
            except ValueError:
                print("Invalid input. Please enter a number.")

    print(f"\nYour total is ${total_cost:.2f}")

if __name__ == '__main__':
    main()
# Out:
# 02_fruit_shop.
# 03_fruit_shop.
# How many (Apple) do you want to buy?: 3
# How many (Durian) do you want to buy?: 4
# How many (Jackfruit) do you want to buy?: 5
# How many (Kiwi) do you want to buy?: 3
# How many (Rambutan) do you want to buy?: 4
# How many (Mango) do you want to buy?: 2
#
# Your total is $623.50

# %%
import hashlib

print("03_powerful_passwords.")

def hash_password(password):
  return hashlib.sha256(password.encode()).hexdigest()

stored_logins = {
    "user@example.com": hash_password("password123"),
    "admin@example.com": hash_password("adminpass")
}

def login(email, password):
  if email in stored_logins:
    return stored_logins[email] == hash_password(password)
    return False

if __name__=="__main__":
  email = input("Enter your email: ")
  password = input("Enter your password: ")

if login(email, password):
  print("Login Successful!")

else:
  print("Invalid email or password.")
# Out:
# 03_powerful_passwords.
# Enter your email: user@example.com
# Enter your password: password123
# Login Successful!
